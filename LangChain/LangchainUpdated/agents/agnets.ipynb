# %%
1+1
# Out:
# 2

# %%
pip install arxiv
# Out:
# Collecting arxiv
#   Downloading arxiv-4.0.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting lxml<7.0,>=6.1.0 (from arxiv)
#   Downloading lxml-6.1.1-cp313-cp313-win_amd64.whl.metadata (3.6 kB)
# Collecting requests<2.34,>=2.32 (from arxiv)
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sahithi.s\documents\my learning\dsa\structured-dsa-python\langchain\langchainupdated\venv\lib\site-packages (from requests<2.34,>=2.32->arxiv) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sahithi.s\documents\my learning\dsa\structured-dsa-python\langchain\langchainupdated\venv\lib\site-packages (from requests<2.34,>=2.32->arxiv) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\sahithi.s\documents\my learning\dsa\structured-dsa-python\langchain\langchainupdated\venv\lib\site-packages (from requests<2.34,>=2.32->arxiv) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\sahithi.s\documents\my learning\dsa\structured-dsa-python\langchain\langchainupdated\venv\lib\site-packages (from requests<2.34,>=2.32->arxiv) (2026.5.20)
# Downloading arxiv-4.0.0-py3-none-any.whl (13 kB)
# Downloading lxml-6.1.1-cp313-cp313-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------------------ --------------------- 1.8/4.0 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 12.8 MB/s eta 0:00:00
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
# Installing collected packages: requests, lxml, arxiv
#   Attempting uninstall: requests
#     Found existing installation: requests 2.34.2
#     Uninstalling requests-2.34.2:
#       Successfully uninstalled requests-2.34.2
# Successfully installed arxiv-4.0.0 lxml-6.1.1 requests-2.33.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install wikipedia
# Out:
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting beautifulsoup4 (from wikipedia)
#   Downloading beautifulsoup4-4.15.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\sahithi.s\documents\my learning\dsa\structured-dsa-python\langchain\langchainupdated\venv\lib\site-packages (from wikipedia) (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sahithi.s\documents\my learning\dsa\structured-dsa-python\langchain\langchainupdated\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sahithi.s\documents\my learning\dsa\structured-dsa-python\langchain\langchainupdated\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\sahithi.s\documents\my learning\dsa\structured-dsa-python\langchain\langchainupdated\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\sahithi.s\documents\my learning\dsa\structured-dsa-python\langchain\langchainupdated\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2026.5.20)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->wikipedia)
#   Downloading soupsieve-2.8.4-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\sahithi.s\documents\my learning\dsa\structured-dsa-python\langchain\langchainupdated\venv\lib\site-packages (from beautifulsoup4->wikipedia) (4.15.0)
# Downloading beautifulsoup4-4.15.0-py3-none-any.whl (109 kB)
# Downloading soupsieve-2.8.4-py3-none-any.whl (37 kB)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (pyproject.toml): started
#   Building wheel for wikipedia (pyproject.toml): finished with status 'done'
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11785 sha256=0f035e7e95c9ff80362266fc61b013bebfdb7e7b1577102a393ca8af666654a7
#   Stored in directory: c:\users\sahithi.s\appdata\local\pip\cache\wheels\79\1d\c8\b64e19423cc5a2a339450ea5d145e7c8eb3d4aa2b150cde33b
# Successfully built wikipedia
# Installing collected packages: soupsieve, beautifulsoup4, wikipedia
# Successfully installed beautifulsoup4-4.15.0 soupsieve-2.8.4 wikipedia-1.4.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

# %%
api_wrapper = WikipediaAPIWrapper(top_k_results=1,doc_content_chars_max=200)
tool = WikipediaQueryRun(api_wrapper=api_wrapper,verbose=True)

# %%
tool.name
# Out:
# 'wikipedia'

# %%
pip install langchain-text-splitters
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement langchain-text-splitter (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for langchain-text-splitter

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

loader = WebBaseLoader("https://en.wikipedia.org/wiki/Artificial_intelligence")
docs=loader.load()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
splits = text_splitter.split_documents(docs)
vectordb=FAISS.from_documents(splits, OpenAIEmbeddings())
retriever = vectordb.as_retriever()
retriever
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[14], line 10
#       6 loader = WebBaseLoader("https://en.wikipedia.org/wiki/Artificial_intelligence")
#       7 docs=loader.load()
#       8 text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
#       9 splits = text_splitter.split_documents(docs)
# ---> 10 vectordb=FAISS.from_documents(splits, OpenAIEmbeddings())
#      11 retriever = vectordb.as_retriever()
#      12 retriever
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\sahithi.s\Documents\My Learning\DSA\structured-dsa-python\LangChain\LangchainUpdated\venv\Lib\site-packages\langchain_openai\embeddings\base.py:452, in OpenAIEmbeddings.validate_environment(self)
#     447         self.http_async_client = httpx.AsyncClient(proxy=self.openai_proxy)
#     448     async_specific = {
#     449         "http_client": self.http_async_client,
#     450         "api_key": async_api_key_value,
#     451     }
# --> 452     self.async_client = openai.AsyncOpenAI(
#     453         **client_params,
#     454         **async_specific,  # type: ignore[arg-type]
#     455     ).embeddings
#     456 return self
#
# File c:\Users\sahithi.s\Documents\My Learning\DSA\structured-dsa-python\LangChain\LangchainUpdated\venv\Lib\site-packages\openai\_client.py:700, in AsyncOpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     691 self.admin_api_key = admin_api_key
#     693 if (
#     694     _enforce_credentials
#     695     and not self.api_key
#    (...)    698     and self.admin_api_key is None
#     699 ):
# --> 700     raise OpenAIError(
#     701         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     702     )
#     704 if organization is None:
#     705     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.
